# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 設定 data_path
dir_data = './data/TW'
f_app_train = os.path.join(dir_data, 'BANK_MCT_ALL_AG.CSV')
app_train = pd.read_csv(f_app_train)

N = 7
under20_means = [app_train['food_<20_price'].mean(), app_train['clothes_<20_price'].mean(), app_train['hotel_<20_price'].mean(), app_train['transpotation_<20_price'].mean(), app_train['entertainment_<20_price'].mean(), app_train['mall_<20_price'].mean(), app_train['other_<20_price'].mean()]
under20_std = [app_train['food_<20_price'].std(), app_train['clothes_<20_price'].std(), app_train['hotel_<20_price'].std(), app_train['transpotation_<20_price'].std(), app_train['entertainment_<20_price'].std(), app_train['mall_<20_price'].std(), app_train['other_<20_price'].std()]

t20to25_means = [app_train['food_20-25_price'].mean(), app_train['clothes_20-25_price'].mean(), app_train['hotel_20-25_price'].mean(), app_train['transpotation_20-25_price'].mean(), app_train['entertainment_20-25_price'].mean(), app_train['mall_20-25_price'].mean(), app_train['other_20-25_price'].mean()]
t20to25_std = [app_train['food_20-25_price'].std(), app_train['clothes_20-25_price'].std(), app_train['hotel_20-25_price'].std(), app_train['transpotation_20-25_price'].std(), app_train['entertainment_20-25_price'].std(), app_train['mall_20-25_price'].std(), app_train['other_20-25_price'].std()]

t25to30_means = [app_train['food_25-30_price'].mean(), app_train['clothes_25-30_price'].mean(), app_train['hotel_25-30_price'].mean(), app_train['transpotation_25-30_price'].mean(), app_train['entertainment_25-30_price'].mean(), app_train['mall_25-30_price'].mean(), app_train['other_25-30_price'].mean()]
t25to30_std = [app_train['food_25-30_price'].std(), app_train['clothes_25-30_price'].std(), app_train['hotel_25-30_price'].std(), app_train['transpotation_25-30_price'].std(), app_train['entertainment_25-30_price'].std(), app_train['mall_25-30_price'].std(), app_train['other_25-30_price'].std()]

t30to35_means = [app_train['food_30-35_price'].mean(), app_train['clothes_30-35_price'].mean(), app_train['hotel_30-35_price'].mean(), app_train['transpotation_30-35_price'].mean(), app_train['entertainment_30-35_price'].mean(), app_train['mall_30-35_price'].mean(), app_train['other_30-35_price'].mean()]
t30to35_std = [app_train['food_30-35_price'].std(), app_train['clothes_30-35_price'].std(), app_train['hotel_30-35_price'].std(), app_train['transpotation_30-35_price'].std(), app_train['entertainment_30-35_price'].std(), app_train['mall_30-35_price'].std(), app_train['other_30-35_price'].std()]

t35to40_means = [app_train['food_35-40_price'].mean(), app_train['clothes_35-40_price'].mean(), app_train['hotel_35-40_price'].mean(), app_train['transpotation_35-40_price'].mean(), app_train['entertainment_35-40_price'].mean(), app_train['mall_35-40_price'].mean(), app_train['other_35-40_price'].mean()]
t35to40_std = [app_train['food_35-40_price'].std(), app_train['clothes_35-40_price'].std(), app_train['hotel_35-40_price'].std(), app_train['transpotation_35-40_price'].std(), app_train['entertainment_35-40_price'].std(), app_train['mall_35-40_price'].std(), app_train['other_35-40_price'].std()]

t40to45_means = [app_train['food_40-45_price'].mean(), app_train['clothes_40-45_price'].mean(), app_train['hotel_40-45_price'].mean(), app_train['transpotation_40-45_price'].mean(), app_train['entertainment_40-45_price'].mean(), app_train['mall_40-45_price'].mean(), app_train['other_40-45_price'].mean()]
t40to45_std = [app_train['food_40-45_price'].std(), app_train['clothes_40-45_price'].std(), app_train['hotel_40-45_price'].std(), app_train['transpotation_40-45_price'].std(), app_train['entertainment_40-45_price'].std(), app_train['mall_40-45_price'].std(), app_train['other_40-45_price'].std()]

t45to50_means = [app_train['food_45-50_price'].mean(), app_train['clothes_45-50_price'].mean(), app_train['hotel_45-50_price'].mean(), app_train['transpotation_45-50_price'].mean(), app_train['entertainment_45-50_price'].mean(), app_train['mall_45-50_price'].mean(), app_train['other_45-50_price'].mean()]
t45to50_std = [app_train['food_45-50_price'].std(), app_train['clothes_45-50_price'].std(), app_train['hotel_45-50_price'].std(), app_train['transpotation_45-50_price'].std(), app_train['entertainment_45-50_price'].std(), app_train['mall_45-50_price'].std(), app_train['other_45-50_price'].std()]

t50to55_means = [app_train['food_50-55_price'].mean(), app_train['clothes_50-55_price'].mean(), app_train['hotel_50-55_price'].mean(), app_train['transpotation_50-55_price'].mean(), app_train['entertainment_50-55_price'].mean(), app_train['mall_50-55_price'].mean(), app_train['other_50-55_price'].mean()]
t50to55_std = [app_train['food_50-55_price'].std(), app_train['clothes_50-55_price'].std(), app_train['hotel_50-55_price'].std(), app_train['transpotation_50-55_price'].std(), app_train['entertainment_50-55_price'].std(), app_train['mall_50-55_price'].std(), app_train['other_50-55_price'].std()]

t55to60_means = [app_train['food_55-60_price'].mean(), app_train['clothes_55-60_price'].mean(), app_train['hotel_55-60_price'].mean(), app_train['transpotation_55-60_price'].mean(), app_train['entertainment_55-60_price'].mean(), app_train['mall_55-60_price'].mean(), app_train['other_55-60_price'].mean()]
t55to60_std = [app_train['food_55-60_price'].std(), app_train['clothes_55-60_price'].std(), app_train['hotel_55-60_price'].std(), app_train['transpotation_55-60_price'].std(), app_train['entertainment_55-60_price'].std(), app_train['mall_55-60_price'].std(), app_train['other_55-60_price'].std()]

t60to65_means = [app_train['food_60-65_price'].mean(), app_train['clothes_60-65_price'].mean(), app_train['hotel_60-65_price'].mean(), app_train['transpotation_60-65_price'].mean(), app_train['entertainment_60-65_price'].mean(), app_train['mall_60-65_price'].mean(), app_train['other_60-65_price'].mean()]
t60to65_std = [app_train['food_60-65_price'].std(), app_train['clothes_60-65_price'].std(), app_train['hotel_60-65_price'].std(), app_train['transpotation_60-65_price'].std(), app_train['entertainment_60-65_price'].std(), app_train['mall_60-65_price'].std(), app_train['other_60-65_price'].std()]

t65to70_means = [app_train['food_65-70_price'].mean(), app_train['clothes_65-70_price'].mean(), app_train['hotel_65-70_price'].mean(), app_train['transpotation_65-70_price'].mean(), app_train['entertainment_65-70_price'].mean(), app_train['mall_65-70_price'].mean(), app_train['other_65-70_price'].mean()]
t65to70_std = [app_train['food_65-70_price'].std(), app_train['clothes_65-70_price'].std(), app_train['hotel_65-70_price'].std(), app_train['transpotation_65-70_price'].std(), app_train['entertainment_65-70_price'].std(), app_train['mall_65-70_price'].std(), app_train['other_65-70_price'].std()]

t70to75_means = [app_train['food_70-75_price'].mean(), app_train['clothes_70-75_price'].mean(), app_train['hotel_70-75_price'].mean(), app_train['transpotation_70-75_price'].mean(), app_train['entertainment_70-75_price'].mean(), app_train['mall_70-75_price'].mean(), app_train['other_70-75_price'].mean()]
t70to75_std = [app_train['food_70-75_price'].std(), app_train['clothes_70-75_price'].std(), app_train['hotel_70-75_price'].std(), app_train['transpotation_70-75_price'].std(), app_train['entertainment_70-75_price'].std(), app_train['mall_70-75_price'].std(), app_train['other_70-75_price'].std()]

t75to80_means = [app_train['food_75-80_price'].mean(), app_train['clothes_75-80_price'].mean(), app_train['hotel_75-80_price'].mean(), app_train['transpotation_75-80_price'].mean(), app_train['entertainment_75-80_price'].mean(), app_train['mall_75-80_price'].mean(), app_train['other_75-80_price'].mean()]
t75to80_std = [app_train['food_75-80_price'].std(), app_train['clothes_75-80_price'].std(), app_train['hotel_75-80_price'].std(), app_train['transpotation_75-80_price'].std(), app_train['entertainment_75-80_price'].std(), app_train['mall_75-80_price'].std(), app_train['other_75-80_price'].std()]

over80_means = [app_train['food_>80_price'].mean(), app_train['clothes_>80_price'].mean(), app_train['hotel_>80_price'].mean(), app_train['transpotation_>80_price'].mean(), app_train['entertainment_>80_price'].mean(), app_train['mall_>80_price'].mean(), app_train['other_>80_price'].mean()]
over80_std = [app_train['food_>80_price'].std(), app_train['clothes_>80_price'].std(), app_train['hotel_>80_price'].std(), app_train['transpotation_>80_price'].std(), app_train['entertainment_>80_price'].std(), app_train['mall_>80_price'].std(), app_train['other_>80_price'].std()]


fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.05        # the width of the bars
ax.bar(ind, under20_means, width, yerr=under20_std, label='<20')
ax.bar(ind + width, t20to25_means, width, yerr=t20to25_std, label='20-25')
ax.bar(ind + width*2, t25to30_means, width, yerr=t25to30_std, label='25-30')
ax.bar(ind + width*3, t30to35_means, width, yerr=t30to35_std, label='30-35')
ax.bar(ind + width*4, t35to40_means, width, yerr=t35to40_std, label='35-40')
ax.bar(ind + width*5, t40to45_means, width, yerr=t40to45_std, label='40-45')
ax.bar(ind + width*6, t45to50_means, width, yerr=t45to50_std, label='45-50')
ax.bar(ind + width*7, t50to55_means, width, yerr=t50to55_std, label='50-55')
ax.bar(ind + width*8, t55to60_means, width, yerr=t55to60_std, label='55-60')
ax.bar(ind + width*9, t60to65_means, width, yerr=t60to65_std, label='60-65')
ax.bar(ind + width*10, t65to70_means, width, yerr=t65to70_std, label='65-70')
ax.bar(ind + width*11, t70to75_means, width, yerr=t70to75_std, label='70-75')
ax.bar(ind + width*12, t75to80_means, width, yerr=t75to80_std, label='75-80')
ax.bar(ind + width*13, over80_means, width, yerr=over80_std, label='>80')

ax.set_ylabel('Price')
ax.set_title('Price by group and age')
ax.set_xticks(ind + width*13 / 7)
ax.set_xticklabels(('food', 'clothes', 'hotel', 'transpotation', 'entertainment', 'mall', 'other'))

ax.legend()
fig.set_size_inches(35, 30, forward=True)
plt.savefig('PricebyAge_meanstd.pdf', dpi=300)

ax.autoscale_view()

plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 設定 data_path
dir_data = './data/TW'
f_app_train = os.path.join(dir_data, 'BANK_MCT_ALL_AG.CSV')
app_train = pd.read_csv(f_app_train)

N = 6
under20_means = [app_train['food_<20_price'].mean(), app_train['clothes_<20_price'].mean(), app_train['hotel_<20_price'].mean(), app_train['transpotation_<20_price'].mean(), app_train['entertainment_<20_price'].mean(), app_train['mall_<20_price'].mean()]
under20_std = [app_train['food_<20_price'].std(), app_train['clothes_<20_price'].std(), app_train['hotel_<20_price'].std(), app_train['transpotation_<20_price'].std(), app_train['entertainment_<20_price'].std(), app_train['mall_<20_price'].std()]

t20to25_means = [app_train['food_20-25_price'].mean(), app_train['clothes_20-25_price'].mean(), app_train['hotel_20-25_price'].mean(), app_train['transpotation_20-25_price'].mean(), app_train['entertainment_20-25_price'].mean(), app_train['mall_20-25_price'].mean()]
t20to25_std = [app_train['food_20-25_price'].std(), app_train['clothes_20-25_price'].std(), app_train['hotel_20-25_price'].std(), app_train['transpotation_20-25_price'].std(), app_train['entertainment_20-25_price'].std(), app_train['mall_20-25_price'].std()]

t25to30_means = [app_train['food_25-30_price'].mean(), app_train['clothes_25-30_price'].mean(), app_train['hotel_25-30_price'].mean(), app_train['transpotation_25-30_price'].mean(), app_train['entertainment_25-30_price'].mean(), app_train['mall_25-30_price'].mean()]
t25to30_std = [app_train['food_25-30_price'].std(), app_train['clothes_25-30_price'].std(), app_train['hotel_25-30_price'].std(), app_train['transpotation_25-30_price'].std(), app_train['entertainment_25-30_price'].std(), app_train['mall_25-30_price'].std()]

t30to35_means = [app_train['food_30-35_price'].mean(), app_train['clothes_30-35_price'].mean(), app_train['hotel_30-35_price'].mean(), app_train['transpotation_30-35_price'].mean(), app_train['entertainment_30-35_price'].mean(), app_train['mall_30-35_price'].mean()]
t30to35_std = [app_train['food_30-35_price'].std(), app_train['clothes_30-35_price'].std(), app_train['hotel_30-35_price'].std(), app_train['transpotation_30-35_price'].std(), app_train['entertainment_30-35_price'].std(), app_train['mall_30-35_price'].std()]

t35to40_means = [app_train['food_35-40_price'].mean(), app_train['clothes_35-40_price'].mean(), app_train['hotel_35-40_price'].mean(), app_train['transpotation_35-40_price'].mean(), app_train['entertainment_35-40_price'].mean(), app_train['mall_35-40_price'].mean()]
t35to40_std = [app_train['food_35-40_price'].std(), app_train['clothes_35-40_price'].std(), app_train['hotel_35-40_price'].std(), app_train['transpotation_35-40_price'].std(), app_train['entertainment_35-40_price'].std(), app_train['mall_35-40_price'].std()]

t40to45_means = [app_train['food_40-45_price'].mean(), app_train['clothes_40-45_price'].mean(), app_train['hotel_40-45_price'].mean(), app_train['transpotation_40-45_price'].mean(), app_train['entertainment_40-45_price'].mean(), app_train['mall_40-45_price'].mean()]
t40to45_std = [app_train['food_40-45_price'].std(), app_train['clothes_40-45_price'].std(), app_train['hotel_40-45_price'].std(), app_train['transpotation_40-45_price'].std(), app_train['entertainment_40-45_price'].std(), app_train['mall_40-45_price'].std()]

t45to50_means = [app_train['food_45-50_price'].mean(), app_train['clothes_45-50_price'].mean(), app_train['hotel_45-50_price'].mean(), app_train['transpotation_45-50_price'].mean(), app_train['entertainment_45-50_price'].mean(), app_train['mall_45-50_price'].mean()]
t45to50_std = [app_train['food_45-50_price'].std(), app_train['clothes_45-50_price'].std(), app_train['hotel_45-50_price'].std(), app_train['transpotation_45-50_price'].std(), app_train['entertainment_45-50_price'].std(), app_train['mall_45-50_price'].std()]

t50to55_means = [app_train['food_50-55_price'].mean(), app_train['clothes_50-55_price'].mean(), app_train['hotel_50-55_price'].mean(), app_train['transpotation_50-55_price'].mean(), app_train['entertainment_50-55_price'].mean(), app_train['mall_50-55_price'].mean()]
t50to55_std = [app_train['food_50-55_price'].std(), app_train['clothes_50-55_price'].std(), app_train['hotel_50-55_price'].std(), app_train['transpotation_50-55_price'].std(), app_train['entertainment_50-55_price'].std(), app_train['mall_50-55_price'].std()]

t55to60_means = [app_train['food_55-60_price'].mean(), app_train['clothes_55-60_price'].mean(), app_train['hotel_55-60_price'].mean(), app_train['transpotation_55-60_price'].mean(), app_train['entertainment_55-60_price'].mean(), app_train['mall_55-60_price'].mean()]
t55to60_std = [app_train['food_55-60_price'].std(), app_train['clothes_55-60_price'].std(), app_train['hotel_55-60_price'].std(), app_train['transpotation_55-60_price'].std(), app_train['entertainment_55-60_price'].std(), app_train['mall_55-60_price'].std()]

t60to65_means = [app_train['food_60-65_price'].mean(), app_train['clothes_60-65_price'].mean(), app_train['hotel_60-65_price'].mean(), app_train['transpotation_60-65_price'].mean(), app_train['entertainment_60-65_price'].mean(), app_train['mall_60-65_price'].mean()]
t60to65_std = [app_train['food_60-65_price'].std(), app_train['clothes_60-65_price'].std(), app_train['hotel_60-65_price'].std(), app_train['transpotation_60-65_price'].std(), app_train['entertainment_60-65_price'].std(), app_train['mall_60-65_price'].std()]

t65to70_means = [app_train['food_65-70_price'].mean(), app_train['clothes_65-70_price'].mean(), app_train['hotel_65-70_price'].mean(), app_train['transpotation_65-70_price'].mean(), app_train['entertainment_65-70_price'].mean(), app_train['mall_65-70_price'].mean()]
t65to70_std = [app_train['food_65-70_price'].std(), app_train['clothes_65-70_price'].std(), app_train['hotel_65-70_price'].std(), app_train['transpotation_65-70_price'].std(), app_train['entertainment_65-70_price'].std(), app_train['mall_65-70_price'].std()]

t70to75_means = [app_train['food_70-75_price'].mean(), app_train['clothes_70-75_price'].mean(), app_train['hotel_70-75_price'].mean(), app_train['transpotation_70-75_price'].mean(), app_train['entertainment_70-75_price'].mean(), app_train['mall_70-75_price'].mean()]
t70to75_std = [app_train['food_70-75_price'].std(), app_train['clothes_70-75_price'].std(), app_train['hotel_70-75_price'].std(), app_train['transpotation_70-75_price'].std(), app_train['entertainment_70-75_price'].std(), app_train['mall_70-75_price'].std()]

t75to80_means = [app_train['food_75-80_price'].mean(), app_train['clothes_75-80_price'].mean(), app_train['hotel_75-80_price'].mean(), app_train['transpotation_75-80_price'].mean(), app_train['entertainment_75-80_price'].mean(), app_train['mall_75-80_price'].mean()]
t75to80_std = [app_train['food_75-80_price'].std(), app_train['clothes_75-80_price'].std(), app_train['hotel_75-80_price'].std(), app_train['transpotation_75-80_price'].std(), app_train['entertainment_75-80_price'].std(), app_train['mall_75-80_price'].std()]

over80_means = [app_train['food_>80_price'].mean(), app_train['clothes_>80_price'].mean(), app_train['hotel_>80_price'].mean(), app_train['transpotation_>80_price'].mean(), app_train['entertainment_>80_price'].mean(), app_train['mall_>80_price'].mean()]
over80_std = [app_train['food_>80_price'].std(), app_train['clothes_>80_price'].std(), app_train['hotel_>80_price'].std(), app_train['transpotation_>80_price'].std(), app_train['entertainment_>80_price'].std(), app_train['mall_>80_price'].std()]


fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.05        # the width of the bars
ax.bar(ind, under20_means, width, yerr=under20_std, label='<20')
ax.bar(ind + width, t20to25_means, width, yerr=t20to25_std, label='20-25')
ax.bar(ind + width*2, t25to30_means, width, yerr=t25to30_std, label='25-30')
ax.bar(ind + width*3, t30to35_means, width, yerr=t30to35_std, label='30-35')
ax.bar(ind + width*4, t35to40_means, width, yerr=t35to40_std, label='35-40')
ax.bar(ind + width*5, t40to45_means, width, yerr=t40to45_std, label='40-45')
ax.bar(ind + width*6, t45to50_means, width, yerr=t45to50_std, label='45-50')
ax.bar(ind + width*7, t50to55_means, width, yerr=t50to55_std, label='50-55')
ax.bar(ind + width*8, t55to60_means, width, yerr=t55to60_std, label='55-60')
ax.bar(ind + width*9, t60to65_means, width, yerr=t60to65_std, label='60-65')
ax.bar(ind + width*10, t65to70_means, width, yerr=t65to70_std, label='65-70')
ax.bar(ind + width*11, t70to75_means, width, yerr=t70to75_std, label='70-75')
ax.bar(ind + width*12, t75to80_means, width, yerr=t75to80_std, label='75-80')
ax.bar(ind + width*13, over80_means, width, yerr=over80_std, label='>80')

ax.set_ylabel('Price')
ax.set_title('Price by group and age')
ax.set_xticks(ind + width*13 / 7)
ax.set_xticklabels(('food', 'clothes', 'hotel', 'transpotation', 'entertainment', 'mall'))

ax.legend()
fig.set_size_inches(30, 25, forward=True)
plt.savefig('PricebyAge_meanstd_noOther.pdf', dpi=300)

ax.autoscale_view()

plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 設定 data_path
dir_data = './data/TW'
f_app_train = os.path.join(dir_data, 'BANK_MCT_ALL_AG.CSV')
app_train = pd.read_csv(f_app_train)

N = 1
under20_means = [app_train['food_<20_price'].mean()]
under20_std = [app_train['food_<20_price'].std()]
t20to25_means = [app_train['food_20-25_price'].mean()]
t20to25_std = [app_train['food_20-25_price'].std()]

t25to30_means = [app_train['food_25-30_price'].mean()]
t25to30_std = [app_train['food_25-30_price'].std()]

t30to35_means = [app_train['food_30-35_price'].mean()]
t30to35_std = [app_train['food_30-35_price'].std()]

t35to40_means = [app_train['food_35-40_price'].mean()]
t35to40_std = [app_train['food_35-40_price'].std()]

t40to45_means = [app_train['food_40-45_price'].mean()]
t40to45_std = [app_train['food_40-45_price'].std()]

t45to50_means = [app_train['food_45-50_price'].mean()]
t45to50_std = [app_train['food_45-50_price'].std()]

t50to55_means = [app_train['food_50-55_price'].mean()]
t50to55_std = [app_train['food_50-55_price'].std()]

t55to60_means = [app_train['food_55-60_price'].mean()]
t55to60_std = [app_train['food_55-60_price'].std()]

t60to65_means = [app_train['food_60-65_price'].mean()]
t60to65_std = [app_train['food_60-65_price'].std()]

t65to70_means = [app_train['food_65-70_price'].mean()]
t65to70_std = [app_train['food_65-70_price'].std()]

t70to75_means = [app_train['food_70-75_price'].mean()]
t70to75_std = [app_train['food_70-75_price'].std()]

t75to80_means = [app_train['food_75-80_price'].mean()]
t75to80_std = [app_train['food_75-80_price'].std()]

over80_means = [app_train['food_>80_price'].mean()]
over80_std = [app_train['food_>80_price'].std()]


fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.05        # the width of the bars
ax.bar(ind, under20_means, width, yerr=under20_std, label='<20')
ax.bar(ind + width, t20to25_means, width, yerr=t20to25_std, label='20-25')
ax.bar(ind + width*2, t25to30_means, width, yerr=t25to30_std, label='25-30')
ax.bar(ind + width*3, t30to35_means, width, yerr=t30to35_std, label='30-35')
ax.bar(ind + width*4, t35to40_means, width, yerr=t35to40_std, label='35-40')
ax.bar(ind + width*5, t40to45_means, width, yerr=t40to45_std, label='40-45')
ax.bar(ind + width*6, t45to50_means, width, yerr=t45to50_std, label='45-50')
ax.bar(ind + width*7, t50to55_means, width, yerr=t50to55_std, label='50-55')
ax.bar(ind + width*8, t55to60_means, width, yerr=t55to60_std, label='55-60')
ax.bar(ind + width*9, t60to65_means, width, yerr=t60to65_std, label='60-65')
ax.bar(ind + width*10, t65to70_means, width, yerr=t65to70_std, label='65-70')
ax.bar(ind + width*11, t70to75_means, width, yerr=t70to75_std, label='70-75')
ax.bar(ind + width*12, t75to80_means, width, yerr=t75to80_std, label='75-80')
ax.bar(ind + width*13, over80_means, width, yerr=over80_std, label='>80')

ax.set_ylabel('Price')
ax.set_title('Price by group and age')
ax.set_xticks(ind + width / 1)
ax.set_xticklabels(('food'))

ax.legend()
fig.set_size_inches(35, 30, forward=True)
plt.savefig('PricebyAge_meanstd_food.pdf', dpi=300)

ax.autoscale_view()

plt.show()
