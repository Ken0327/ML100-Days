# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# data_path
dir_data = './data/TW'
f_app_train = os.path.join(dir_data, 'fakedata.CSV')
app_train = pd.read_csv(f_app_train)

# %%
app_train.head()
# Out:
#   member_id  postal_cd date_cd department  index   prod_id  \
# 0    abc123        813   day10         3C   藍芽耳機  11111111
# 1    abc123        813   day11         3C  運動攝影機  11111112
# 2    abc123        815   day12    Clothes     球鞋  11111113
# 3    abc123        816   day13         3C     手機  11111114
# 4    abc127        817   day14    Clothes     服飾  11111115
#
#                            goods  price   MSRP
# 0  Apple AirPods Pro (MWP22TA/A)   7359   8000
# 1                   GoPro HERO 8  15000  16000
# 2                    Nike Jordan   6800   7500
# 3                      iPhone 11  22900  24000
# 4                    Edwin jeans   1600   2000

# %%
# calculate DFM data

df = app_train.copy()

df1 = df.groupby('member_id').agg({'date_cd': np.size})
df2 = df.groupby('member_id')['price'].sum()
df3 = df.groupby('member_id')['MSRP'].sum()

df1['Monetary'] = df2
df1['MSRP_Total'] = df3
df3 = df1.rename(columns={'date_cd':'Frequency'})

discount = []

for i in df3.index:
    discount.append(1 - round(df3['Monetary'][i]/df3['MSRP_Total'][i], 3))

df3['Discount'] = discount

df4 = pd.DataFrame()
df4['Discount'] = df3['Discount']
df4['Frequency'] = df3['Frequency']
df4['Monetary'] = df3['Monetary']
df4.head()
# Out:
#            Discount  Frequency  Monetary
# member_id
# abc123        0.062          4     52059
# abc124        0.080          1      7359
# abc125        0.062          1     15000
# abc126        0.093          1      6800
# abc127        0.068          3     26100

# %%
# Plot DFM distributions

plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(df4['Discount'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(df4['Frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(df4['Monetary'])
# Show the plot
plt.show()
# Out:
# C:\Users\chenken\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Calculate z score
from scipy.stats import zscore

df = df4.apply(zscore)

df4['D_z-score'] = df['Discount']
df4['F_z-score'] = df['Frequency']
df4['M_z-score'] = df['Monetary']
df4.head()
# Out:
#            Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score
# member_id
# abc123        0.062          4     52059  -0.945510   1.860958   2.353982
# abc124        0.080          1      7359  -0.642767  -0.548916  -0.635053
# abc125        0.062          1     15000  -0.945510  -0.548916  -0.124108
# abc126        0.093          1      6800  -0.424120  -0.548916  -0.672433
# abc127        0.068          3     26100  -0.844596   1.057667   0.618135

# %%
# calculate VS(Value Score)＝ 1.25*ZD + 1* ZF + 1.5* ZM, Weight of DFM
vsScore = []

for i in df4.index:
    vsScore.append(1.25 * df4['D_z-score'][i] + 1 * df4['F_z-score'][i] + 1.5 * df4['M_z-score'][i])

df4['ValueScore'] = vsScore
df4.head()
# Out:
#            Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# member_id
# abc123        0.062          4     52059  -0.945510   1.860958   2.353982
# abc124        0.080          1      7359  -0.642767  -0.548916  -0.635053
# abc125        0.062          1     15000  -0.945510  -0.548916  -0.124108
# abc126        0.093          1      6800  -0.424120  -0.548916  -0.672433
# abc127        0.068          3     26100  -0.844596   1.057667   0.618135
#
#            ValueScore
# member_id
# abc123       4.210044
# abc124      -2.304954
# abc125      -1.916966
# abc126      -2.087714
# abc127       0.929125

# %%
# Rank by Value Score 
df4['Rank_ValueScore'] = df4['ValueScore'].rank(method='min', ascending=False)
df5 = df4.sort_values(by='ValueScore', ascending=False)
result = df5.reset_index()
result.index += 1
result.head()
# Out:
#   member_id  Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# 1    abc128     0.171          6     67180   0.887765   3.467541   3.365105
# 2    abc168     0.198          6     48270   1.341878   3.467541   2.100616
# 3    abc148     0.196          4     25170   1.308240   1.860958   0.555947
# 4    abc163     0.061          4     53059  -0.962329   1.860958   2.420851
# 5    abc123     0.062          4     52059  -0.945510   1.860958   2.353982
#
#    ValueScore  Rank_ValueScore
# 1    9.624904              1.0
# 2    8.295813              2.0
# 3    4.330179              3.0
# 4    4.289323              4.0
# 5    4.210044              5.0

# %%
# Top 20 % valuable customer
valuable = []
for i in result.index:
    if i <= (len(result.index) * 0.2):
        valuable.append('Valuable Customer')
    else:
        valuable.append('Potential Customer')

result['VS Level'] = valuable
result
# Out:
#    member_id  Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# 1     abc128     0.171          6     67180   0.887765   3.467541   3.365105
# 2     abc168     0.198          6     48270   1.341878   3.467541   2.100616
# 3     abc148     0.196          4     25170   1.308240   1.860958   0.555947
# 4     abc163     0.061          4     53059  -0.962329   1.860958   2.420851
# 5     abc123     0.062          4     52059  -0.945510   1.860958   2.353982
# 6     abc170     0.320          1     11500   3.393800  -0.548916  -0.358149
# 7     abc133     0.075          4     36518  -0.726863   1.860958   1.314774
# 8     abc183     0.057          3     45259  -1.029605   1.057667   1.899274
# 9     abc143     0.057          3     45259  -1.029605   1.057667   1.899274
# 10    abc130     0.201          1     21500   1.392336  -0.548916   0.310539
# 11    abc196     0.201          1     21500   1.392336  -0.548916   0.310539
# 12    abc189     0.201          1     21500   1.392336  -0.548916   0.310539
# 13    abc156     0.187          1     23500   1.156869  -0.548916   0.444276
# 14    abc149     0.146          1     31500   0.467289  -0.548916   0.979227
# 15    abc173     0.074          3     29159  -0.743682   1.057667   0.822687
# 16    abc131     0.104          3     21490  -0.239111   1.057667   0.309870
# 17    abc171     0.104          3     21490  -0.239111   1.057667   0.309870
# 18    abc167     0.068          3     26100  -0.844596   1.057667   0.618135
# 19    abc127     0.068          3     26100  -0.844596   1.057667   0.618135
# 20    abc188     0.164          3      3670   0.770031   1.057667  -0.881732
# 21    abc147     0.200          2      3200   1.375517   0.254376  -0.913160
# 22    abc187     0.200          2      3200   1.375517   0.254376  -0.913160
# 23    abc172     0.092          2     17259  -0.440939   0.254376   0.026948
# 24    abc194     0.200          1      1600   1.375517  -0.548916  -1.020150
# 25    abc154     0.200          1      1600   1.375517  -0.548916  -1.020150
# 26    abc169     0.175          1       990   0.955041  -0.548916  -1.060940
# 27    abc129     0.175          1       990   0.955041  -0.548916  -1.060940
# 28    abc155     0.175          1       990   0.955041  -0.548916  -1.060940
# 29    abc195     0.175          1       990   0.955041  -0.548916  -1.060940
# 30    abc178     0.151          1      1690   0.551384  -0.548916  -1.014132
# 31    abc157     0.151          1      1690   0.551384  -0.548916  -1.014132
# 32    abc190     0.151          1      1690   0.551384  -0.548916  -1.014132
# 33    abc150     0.151          1      1690   0.551384  -0.548916  -1.014132
# 34    abc138     0.151          1      1690   0.551384  -0.548916  -1.014132
# 35    abc197     0.151          1      1690   0.551384  -0.548916  -1.014132
# 36    abc176     0.046          1     22900  -1.214614  -0.548916   0.404155
# 37    abc186     0.046          1     22900  -1.214614  -0.548916   0.404155
# 38    abc193     0.046          1     22900  -1.214614  -0.548916   0.404155
# 39    abc146     0.046          1     22900  -1.214614  -0.548916   0.404155
# 40    abc136     0.046          1     22900  -1.214614  -0.548916   0.404155
# 41    abc153     0.046          1     22900  -1.214614  -0.548916   0.404155
# 42    abc191     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 43    abc181     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 44    abc198     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 45    abc158     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 46    abc151     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 47    abc141     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 48    abc132     0.100          1      9900  -0.306387  -0.548916  -0.465139
# 49    abc174     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 50    abc125     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 51    abc152     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 52    abc192     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 53    abc134     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 54    abc165     0.062          1     15000  -0.945510  -0.548916  -0.124108
# 55    abc175     0.093          1      6800  -0.424120  -0.548916  -0.672433
# 56    abc166     0.093          1      6800  -0.424120  -0.548916  -0.672433
# 57    abc126     0.093          1      6800  -0.424120  -0.548916  -0.672433
# 58    abc135     0.093          1      6800  -0.424120  -0.548916  -0.672433
# 59    abc164     0.080          1      7359  -0.642767  -0.548916  -0.635053
# 60    abc124     0.080          1      7359  -0.642767  -0.548916  -0.635053
#
#     ValueScore  Rank_ValueScore            VS Level
# 1     9.624904              1.0   Valuable Customer
# 2     8.295813              2.0   Valuable Customer
# 3     4.330179              3.0   Valuable Customer
# 4     4.289323              4.0   Valuable Customer
# 5     4.210044              5.0   Valuable Customer
# 6     3.156111              6.0   Valuable Customer
# 7     2.924541              7.0   Valuable Customer
# 8     2.619572              8.0   Valuable Customer
# 9     2.619572              8.0   Valuable Customer
# 10    1.657312             10.0   Valuable Customer
# 11    1.657312             10.0   Valuable Customer
# 12    1.657312             10.0   Valuable Customer
# 13    1.563585             13.0  Potential Customer
# 14    1.504035             14.0  Potential Customer
# 15    1.362095             15.0  Potential Customer
# 16    1.223584             16.0  Potential Customer
# 17    1.223584             16.0  Potential Customer
# 18    0.929125             18.0  Potential Customer
# 19    0.929125             18.0  Potential Customer
# 20    0.697608             20.0  Potential Customer
# 21    0.604031             21.0  Potential Customer
# 22    0.604031             21.0  Potential Customer
# 23   -0.256376             23.0  Potential Customer
# 24   -0.359745             24.0  Potential Customer
# 25   -0.359745             24.0  Potential Customer
# 26   -0.946525             26.0  Potential Customer
# 27   -0.946525             26.0  Potential Customer
# 28   -0.946525             26.0  Potential Customer
# 29   -0.946525             26.0  Potential Customer
# 30   -1.380884             30.0  Potential Customer
# 31   -1.380884             30.0  Potential Customer
# 32   -1.380884             30.0  Potential Customer
# 33   -1.380884             30.0  Potential Customer
# 34   -1.380884             30.0  Potential Customer
# 35   -1.380884             30.0  Potential Customer
# 36   -1.460951             36.0  Potential Customer
# 37   -1.460951             36.0  Potential Customer
# 38   -1.460951             36.0  Potential Customer
# 39   -1.460951             36.0  Potential Customer
# 40   -1.460951             36.0  Potential Customer
# 41   -1.460951             36.0  Potential Customer
# 42   -1.629608             42.0  Potential Customer
# 43   -1.629608             42.0  Potential Customer
# 44   -1.629608             42.0  Potential Customer
# 45   -1.629608             42.0  Potential Customer
# 46   -1.629608             42.0  Potential Customer
# 47   -1.629608             42.0  Potential Customer
# 48   -1.629608             42.0  Potential Customer
# 49   -1.916966             49.0  Potential Customer
# 50   -1.916966             49.0  Potential Customer
# 51   -1.916966             49.0  Potential Customer
# 52   -1.916966             49.0  Potential Customer
# 53   -1.916966             49.0  Potential Customer
# 54   -1.916966             49.0  Potential Customer
# 55   -2.087714             55.0  Potential Customer
# 56   -2.087714             55.0  Potential Customer
# 57   -2.087714             55.0  Potential Customer
# 58   -2.087714             55.0  Potential Customer
# 59   -2.304954             59.0  Potential Customer
# 60   -2.304954             59.0  Potential Customer
