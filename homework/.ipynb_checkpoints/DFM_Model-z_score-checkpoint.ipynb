# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# data_path
dir_data = './data/TW'
f_app_train = os.path.join(dir_data, 'fakedata.CSV')
app_train = pd.read_csv(f_app_train)

# %%
app_train.head()
# Out:
#   member_id  postal_cd date_cd department  index   prod_id  \
# 0    abc123        813   day10         3C   藍芽耳機  11111111
# 1    abc123        813   day11         3C  運動攝影機  11111112
# 2    abc123        815   day12    Clothes     球鞋  11111113
# 3    abc123        816   day13         3C     手機  11111114
# 4    abc127        817   day14    Clothes     服飾  11111115
#
#                            goods  price   MSRP
# 0  Apple AirPods Pro (MWP22TA/A)   7359   8000
# 1                   GoPro HERO 8  15000  16000
# 2                    Nike Jordan   6800   7500
# 3                      iPhone 11  22900  24000
# 4                    Edwin jeans   1600   2000

# %%
# calculate DFM data

df = app_train.copy()

df1 = df.groupby('member_id').agg({'date_cd': np.size})
df2 = df.groupby('member_id')['price'].sum()
df3 = df.groupby('member_id')['MSRP'].sum()

df1['Monetary'] = df2
df1['MSRP_Total'] = df3
df3 = df1.rename(columns={'date_cd':'Frequency'})

discount = []

for i in df3.index:
    discount.append(1 - round(df3['Monetary'][i]/df3['MSRP_Total'][i], 3))

df3['Discount'] = discount

df4 = pd.DataFrame()
df4['Discount'] = df3['Discount']
df4['Frequency'] = df3['Frequency']
df4['Monetary'] = df3['Monetary']
df4.head()
# Out:
#            Discount  Frequency  Monetary
# member_id
# abc123        0.062          4     52059
# abc124        0.080          1      7359
# abc125        0.062          1     15000
# abc126        0.093          1      6800
# abc127        0.068          3     26100

# %%
# Plot DFM distributions

plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(df4['Discount'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(df4['Frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(df4['Monetary'])
# Show the plot
plt.show()
# Out:
# C:\Users\chenken\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Calculate z score
from scipy.stats import zscore

df = df4.apply(zscore)

df4['D_z-score'] = df['Discount']
df4['F_z-score'] = df['Frequency']
df4['M_z-score'] = df['Monetary']
df4.head()
# Out:
#            Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score
# member_id
# abc123        0.062          4     52059  -0.996553   1.822177   2.530456
# abc124        0.080          1      7359  -0.676232  -0.537477  -0.649674
# abc125        0.062          1     15000  -0.996553  -0.537477  -0.106064
# abc126        0.093          1      6800  -0.444890  -0.537477  -0.689443
# abc127        0.068          3     26100  -0.889779   1.035626   0.683633

# %%
# calculate VS(Value Score)＝ 1.25*ZD + 1* ZF + 1.5* ZM, Weight of DFM
vsScore = []

for i in df4.index:
    vsScore.append(1.25 * df4['D_z-score'][i] + 1 * df4['F_z-score'][i] + 1.5 * df4['M_z-score'][i])

df4['ValueScore'] = vsScore
df4.head()
# Out:
#            Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# member_id
# abc123        0.062          4     52059  -0.996553   1.822177   2.530456
# abc124        0.080          1      7359  -0.676232  -0.537477  -0.649674
# abc125        0.062          1     15000  -0.996553  -0.537477  -0.106064
# abc126        0.093          1      6800  -0.444890  -0.537477  -0.689443
# abc127        0.068          3     26100  -0.889779   1.035626   0.683633
#
#            ValueScore
# member_id
# abc123       4.372171
# abc124      -2.357278
# abc125      -1.942263
# abc126      -2.127754
# abc127       0.948851

# %%
# Rank by Value Score 
df4['Rank_ValueScore'] = df4['ValueScore'].rank(method='min', ascending=False)
df5 = df4.sort_values(by='ValueScore', ascending=False)
result = df5.reset_index()
result.index += 1
result.head()
# Out:
#   member_id  Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# 1    abc128     0.198          6     48270   1.423647   3.395280   2.260892
# 2    abc168     0.198          6     48270   1.423647   3.395280   2.260892
# 3    abc148     0.196          4     25170   1.388056   1.822177   0.617469
# 4    abc123     0.062          4     52059  -0.996553   1.822177   2.530456
# 5    abc163     0.062          4     52059  -0.996553   1.822177   2.530456
#
#    ValueScore  Rank_ValueScore
# 1    8.566177              1.0
# 2    8.566177              1.0
# 3    4.483451              3.0
# 4    4.372171              4.0
# 5    4.372171              4.0

# %%
# Top 20 valuable customer
valuable = []
for i in result.index:
    if i <= 20:
        valuable.append('Valuable Customer')
    else:
        valuable.append('Potential Customer')

result['VS Level'] = valuable
result
# Out:
#    member_id  Discount  Frequency  Monetary  D_z-score  F_z-score  M_z-score  \
# 1     abc128     0.198          6     48270   1.423647   3.395280   2.260892
# 2     abc168     0.198          6     48270   1.423647   3.395280   2.260892
# 3     abc148     0.196          4     25170   1.388056   1.822177   0.617469
# 4     abc123     0.062          4     52059  -0.996553   1.822177   2.530456
# 5     abc163     0.062          4     52059  -0.996553   1.822177   2.530456
# 6     abc173     0.075          4     36518  -0.765210   1.822177   1.424810
# 7     abc133     0.075          4     36518  -0.765210   1.822177   1.424810
# 8     abc143     0.057          3     45259  -1.085531   1.035626   2.046678
# 9     abc183     0.057          3     45259  -1.085531   1.035626   2.046678
# 10    abc170     0.201          1     21500   1.477034  -0.537477   0.356371
# 11    abc149     0.201          1     21500   1.477034  -0.537477   0.356371
# 12    abc189     0.201          1     21500   1.477034  -0.537477   0.356371
# 13    abc156     0.201          1     21500   1.477034  -0.537477   0.356371
# 14    abc196     0.201          1     21500   1.477034  -0.537477   0.356371
# 15    abc130     0.201          1     21500   1.477034  -0.537477   0.356371
# 16    abc171     0.104          3     21490  -0.249138   1.035626   0.355660
# 17    abc131     0.104          3     21490  -0.249138   1.035626   0.355660
# 58    abc175     0.093          1      6800  -0.444890  -0.537477  -0.689443
# 59    abc124     0.080          1      7359  -0.676232  -0.537477  -0.649674
# 60    abc164     0.080          1      7359  -0.676232  -0.537477  -0.649674
#
#     ValueScore  Rank_ValueScore            VS Level
# 1     8.566177              1.0   Valuable Customer
# 2     8.566177              1.0   Valuable Customer
# 3     4.483451              3.0   Valuable Customer
# 4     4.372171              4.0   Valuable Customer
# 5     4.372171              4.0   Valuable Customer
# 6     3.002879              6.0   Valuable Customer
# 7     3.002879              6.0   Valuable Customer
# 8     2.748730              8.0   Valuable Customer
# 9     2.748730              8.0   Valuable Customer
# 10    1.843372             10.0   Valuable Customer
# 11    1.843372             10.0   Valuable Customer
# 12    1.843372             10.0   Valuable Customer
# 13    1.843372             10.0   Valuable Customer
# 14    1.843372             10.0   Valuable Customer
# 15    1.843372             10.0   Valuable Customer
# 16    1.257693             16.0   Valuable Customer
# 17    1.257693             16.0   Valuable Customer
# 18    0.948851             18.0   Valuable Customer
# 19    0.948851             18.0   Valuable Customer
# 20    0.690687             20.0   Valuable Customer
# 21    0.654781             21.0  Potential Customer
# 22    0.654781             21.0  Potential Customer
# 23   -0.302516             23.0  Potential Customer
# 24   -0.302516             23.0  Potential Customer
# 25   -0.923725             25.0  Potential Customer
# 26   -0.923725             25.0  Potential Customer
# 27   -0.923725             25.0  Potential Customer
# 28   -0.923725             25.0  Potential Customer
# 29   -1.382891             29.0  Potential Customer
# 30   -1.382891             29.0  Potential Customer
# 31   -1.382891             29.0  Potential Customer
# 32   -1.382891             29.0  Potential Customer
# 33   -1.382891             29.0  Potential Customer
# 34   -1.382891             29.0  Potential Customer
# 35   -1.455120             35.0  Potential Customer
# 36   -1.455120             35.0  Potential Customer
# 37   -1.455120             35.0  Potential Customer
# 38   -1.455120             35.0  Potential Customer
# 39   -1.455120             35.0  Potential Customer
# 40   -1.455120             35.0  Potential Customer
# 41   -1.641223             41.0  Potential Customer
# 42   -1.641223             41.0  Potential Customer
# 43   -1.641223             41.0  Potential Customer
# 44   -1.641223             41.0  Potential Customer
# 45   -1.641223             41.0  Potential Customer
# 46   -1.641223             41.0  Potential Customer
# 47   -1.641223             41.0  Potential Customer
# 48   -1.641223             41.0  Potential Customer
# 49   -1.942263             49.0  Potential Customer
# 50   -1.942263             49.0  Potential Customer
# 51   -1.942263             49.0  Potential Customer
# 52   -1.942263             49.0  Potential Customer
# 53   -1.942263             49.0  Potential Customer
# 54   -1.942263             49.0  Potential Customer
# 55   -2.127754             55.0  Potential Customer
# 56   -2.127754             55.0  Potential Customer
# 57   -2.127754             55.0  Potential Customer
# 58   -2.127754             55.0  Potential Customer
# 59   -2.357278             59.0  Potential Customer
# 60   -2.357278             59.0  Potential Customer
